# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
present = pd.read_csv('data_predict/PRESENT_ch4_knn.csv')
ssp126 = pd.read_csv('data_predict/ssp126_ch4_knn.csv')
ssp585 = pd.read_csv('data_predict/ssp585_ch4_knn.csv')

# %%
ssp126.columns
# Out:
# Index(['Unnamed: 0', 'field_1', 'GRAND_ID', 'EHA_PID', 'Distance', 'RES_NAME',
#        'DAM_NAME', 'ALT_NAME', 'RIVER', 'ALT_RIVER',
#        ...
#        'Age', 'Area_km2', 'Volume_km3', 'mcm_cap_km3', 'precip',
#        'ch4_emissions_logscale', 'ch4_emissions', 'ch4_emissions_present',
#        'ch4_ssp126_present_diff', 'ch4_ssp126_present_diff.1'],
#       dtype='object', length=116)

# %%
ssp126.rename(columns = {'ch4_ssp126_present_diff':'ssp126'}, inplace = True) 
ssp585.rename(columns = {'ch4_ssp585_present_diff':'ssp585'}, inplace = True)

# %%
ssp126.columns
# Out:
# Index(['Unnamed: 0', 'field_1', 'GRAND_ID', 'EHA_PID', 'Distance', 'RES_NAME',
#        'DAM_NAME', 'ALT_NAME', 'RIVER', 'ALT_RIVER',
#        ...
#        'Age', 'Area_km2', 'Volume_km3', 'mcm_cap_km3', 'precip',
#        'ch4_emissions_logscale', 'ch4_emissions', 'ch4_emissions_present',
#        'ssp126', 'ch4_ssp126_present_diff.1'],
#       dtype='object', length=116)

# %%
# library and dataset
 
# plot of 2 variables
fsize = (15, 20)

p1=sns.kdeplot(ssp126['ssp126'], shade=True, color="sandybrown")
p1=sns.kdeplot(ssp585['ssp585'], shade=True, color="deepskyblue")
p1.set(xlim=(-1000, 1000), xlabel='CH(projection) - CH(present)', ylabel='Density')
p1.legend(loc='upper left')



#sns.plt.show()

# %%
# library and dataset
 
# plot of 2 variables
sns.set_style("white")
g = sns.kdeplot(x="ssp126", data=ssp126, aspect=2)
g = (g.set_axis_labels("CH(projection) - CH(present)","Density").set(xlim=(-1000,1000))
plt.title("title")
plt.show(g)
# Out:
#   File "<ipython-input-90-fa409441ebca>", line 7
#     g.title("title")
#     ^
# SyntaxError: invalid syntax

# %%
sns.set(style="white", palette="muted", color_codes=True)
rs = np.random.RandomState(10)

# Set up the matplotlib figure
f, axes = plt.subplots(2, 1, figsize=(7, 7), sharex=True)
sns.despine(left=True)

# Plot a simple histogram with binsize determined automatically
sns.distplot(ssp126['ssp126'], hist=False, color="b", kde_kws={"shade": True}, ax=axes[0])
sns.distplot(ssp585['ssp585'], hist=False, color="g", kde_kws={"shade": True}, ax=axes[0])

# # Plot a kernel density estimate and rug plot
# sns.distplot(d, hist=False, color="r", ax=axes[0, 1])

# Plot a filled kernel density estimate
sns.distplot(ssp585['ssp585'], hist=False, color="g", kde_kws={"shade": True}, ax=axes[1])

# # Plot a histogram and kernel density estimate
# sns.distplot(d, color="m", ax=axes[1, 1])

plt.xlim(-2500,2500)
plt.ylim(0,2500)
plt.setp(axes)
plt.tight_layout()
# Out:
#   adjustable: {'box', 'datalim'}
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array
#   alpha: float
#   anchor: 2-tuple of floats or {'C', 'SW', 'S', 'SE', ...}
#   animated: bool
#   aspect: {'auto', 'equal'} or num
#   autoscale_on: bool
#   autoscalex_on: bool
#   autoscaley_on: bool
#   axes_locator: Callable[[Axes, Renderer], Bbox]
#   axisbelow: bool or 'line'
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: [(`~matplotlib.path.Path`, `.Transform`) | `.Patch` | None]
#   contains: callable
#   facecolor: color
#   fc: color
#   figure: `.Figure`
#   frame_on: bool
#   gid: str
#   in_layout: bool
#   label: object
#   navigate: bool
#   navigate_mode: unknown
#   path_effects: `.AbstractPathEffect`
#   picker: None or bool or float or callable
#   position: [left, bottom, width, height] or `~matplotlib.transforms.Bbox`
#   rasterization_zorder: float or None
#   rasterized: bool or None
# ...

# %%
sns.set(style="white", palette="muted", color_codes=True)
rs = np.random.RandomState(10)

# Set up the matplotlib figure
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
sns.despine(left=True)

# Generate a random univariate dataset
d = rs.normal(size=100)

# Plot a simple histogram with binsize determined automatically
sns.distplot(d, kde=False, color="b", ax=axes[0, 0])

# Plot a kernel density estimate and rug plot
sns.distplot(d, hist=False, rug=True, color="r", ax=axes[0, 1])

# Plot a filled kernel density estimate
sns.distplot(d, hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])

# Plot a histogram and kernel density estimate
sns.distplot(d, color="m", ax=axes[1, 1])

plt.setp(axes, yticks=[])
plt.tight_layout()
