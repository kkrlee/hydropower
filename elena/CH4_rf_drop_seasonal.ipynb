# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/training_final_latcorr.csv')

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#      field_1                 Name  Longitude   Latitude  CO2 (mg C m¯² d¯¹)  \
# 0        116              Segredo -52.100000 -25.783333               600.0
# 1        117              Segredo -52.100000 -25.783333              1306.1
# 2         45               Itaipu -54.550000 -25.383333               328.6
# 3        104  RibeirÃ£o das Lages -43.883333 -22.700000                22.1
# 4          7         Barra Bonita -48.583333 -22.516667              1036.4
# ..       ...                  ...        ...        ...                 ...
# 149       68                 Lule  21.666667  65.833333                12.3
# 150       66                Lokka  27.733333  67.816667               545.5
# 151       67                Lokka  27.733333  67.816667               288.0
# 152      100          Porttipahta  26.750000  68.000000               572.7
# 153      101          Porttipahta  26.750000  68.000000               420.0
#
#      CH4 (mg C m-2 d-1)  CO2 (g/kWh)  CH4 (g/kWh)  Area / Electricity  \
# 0                  29.9    15.167696     0.274857            0.018889
# 1                   5.0    33.017545     0.045963            0.018889
# 2                   NaN     6.603175          NaN            0.015015
# 3                   NaN          NaN          NaN                 NaN
# 4                   9.9  3187.260766    11.071149            2.297872
# ..                  ...          ...          ...                 ...
# 149                 NaN    20.541089          NaN            1.247826
# 150                79.0   632.052667    33.285333            0.865753
# 151               115.0   333.696000    48.453333            0.865753
# 152                13.0  1623.991970    13.405017            2.118812
# 153                 6.0  1190.984158     6.186931            2.118812
#
#      Area_km2   Age  Volume_km3  Areakm2_div_Volkm3      org_c  \
# 0        82.0  13.0         3.0           27.333333  48.768551
# 1        82.0  13.0         3.0           27.333333  48.768551
# 2      1350.0  14.0       129.0           10.465116  44.606594
# 3        30.0  95.0         0.5           60.000000  60.257137
# 4       324.0  42.0         4.0           81.000000  37.520664
# ..        ...   ...         ...                 ...        ...
# 149     574.0  70.0         NaN                 NaN  61.908791
# 150     316.0  28.0         2.1          150.476191  60.026501
# 151     316.0  28.0         2.1          150.476191  60.026501
# 152     214.0  25.0         1.4          152.857143  59.067596
# 153     214.0  25.0         1.4          152.857143  59.067596
#
#      temp_annual_avg  temp_spring_avg_lc  temp_spring_avg  temp_summer_avg_lc  \
# 0          17.059999           18.243999        17.054667           20.768000
# 1          17.059999           18.243999        17.054667           20.768000
# 2          21.125334           21.429333        21.202667           25.158667
# 3          20.374001           20.393333        20.902666           23.022667
# 4          20.853001           21.605333        20.834667           23.501333
# ..               ...                 ...              ...                 ...
# 149         1.616667            0.884000         0.884000           14.160000
# 150        -1.679333           -3.041333        -3.041333           11.264000
# 151        -1.679333           -3.041333        -3.041333           11.264000
# 152        -1.365000           -2.257334        -2.257334           11.521333
# 153        -1.365000           -2.257334        -2.257334           11.521333
#
#      temp_summer_avg  temp_fall_avg_lc  temp_fall_avg  temp_winter_avg_lc  \
# 0          13.137333         17.054667      18.243999           13.137333
# 1          13.137333         17.054667      18.243999           13.137333
# 2          16.773333         21.202667      21.429333           16.773333
# 3          17.549334         20.902666      20.393333           17.549334
# 4          17.721333         20.834667      21.605333           17.721333
# ..               ...               ...            ...                 ...
# 149        14.160000          1.786667       1.786667          -10.181334
# 150        11.264000         -1.165333      -1.165333          -13.594666
# 151        11.264000         -1.165333      -1.165333          -13.594666
# 152        11.521333         -1.256000      -1.256000          -13.422667
# 153        11.521333         -1.256000      -1.256000          -13.422667
#
#      temp_winter_avg  NDVI_annual_avg  NDVI_spring_avg_lc  NDVI_spring_avg  \
# 0          20.768000       200.666672          212.666672       221.333328
# 1          20.768000       200.666672          212.666672       221.333328
# 2          25.158667       255.000000          255.000000       255.000000
# 3          23.022667       232.333328          226.000000       242.333328
# 4          23.501333       160.250000          123.666664       178.333328
# ..               ...              ...                 ...              ...
# 149       -10.181334       131.750000          106.333336       106.333336
# 150       -13.594666       255.000000          255.000000       255.000000
# 151       -13.594666       255.000000          255.000000       255.000000
# 152       -13.422667       255.000000          255.000000       255.000000
# 153       -13.422667       255.000000          255.000000       255.000000
#
#      NDVI_summer_avg_lc  NDVI_summer_avg  NDVI_fall_avg_lc  NDVI_fall_avg  \
# 0            238.666672       219.333328        221.333328     212.666672
# 1            238.666672       219.333328        221.333328     212.666672
# 2            255.000000       255.000000        255.000000     255.000000
# 3            237.666672       223.333328        242.333328     226.000000
# 4            187.333328       151.666672        178.333328     123.666664
# ..                  ...              ...               ...            ...
# 149          226.000000       226.000000        159.333328     159.333328
# 150          255.000000       255.000000        255.000000     255.000000
# 151          255.000000       255.000000        255.000000     255.000000
# 152          255.000000       255.000000        255.000000     255.000000
# 153          255.000000       255.000000        255.000000     255.000000
#
#      NDVI_winter_avg_lc  NDVI_winter_avg  npp_annual_avg  npp_spring_avg_lc  \
# 0            219.333328       238.666672      200.500000         212.000000
# 1            219.333328       238.666672      200.500000         212.000000
# 2            255.000000       255.000000       87.000000          79.000000
# 3            223.333328       237.666672      151.416672         153.333328
# 4            151.666672       187.333328      132.750000          94.000000
# ..                  ...              ...             ...                ...
# 149           35.333332        35.333332       99.250000          58.333332
# 150          255.000000       255.000000       95.583336          47.666668
# 151          255.000000       255.000000       95.583336          47.666668
# 152          255.000000       255.000000       90.250000          46.333332
# 153          255.000000       255.000000       90.250000          46.333332
#
#      npp_spring_avg  npp_summer_avg_lc  npp_summer_avg  npp_fall_avg_lc  \
# 0        207.666672         202.000000      180.333328       207.666672
# 1        207.666672         202.000000      180.333328       207.666672
# 2         85.333336          87.000000       96.666664        85.333336
# 3        179.333328         156.666672      170.666672       179.333328
# 4        166.000000         130.000000      141.000000       166.000000
# ..              ...                ...             ...              ...
# 149       58.333332         180.333328      180.333328        51.333332
# 150       47.666668         114.000000      114.000000        39.666668
# 151       47.666668         114.000000      114.000000        39.666668
# 152       46.333332         122.000000      122.000000        40.666668
# 153       46.333332         122.000000      122.000000        40.666668
#
#      npp_fall_avg  npp_winter_avg_lc  npp_winter_avg    erosion
# 0      212.000000         180.333328      202.000000  21.503389
# 1      212.000000         180.333328      202.000000  21.503389
# 2       79.000000          96.666664       87.000000  32.145058
# 3      153.333328         170.666672      156.666672   0.541019
# 4       94.000000         141.000000      130.000000   7.974369
# ..            ...                ...             ...        ...
# 149     51.333332         107.000000      107.000000   0.004779
# 150     39.666668         181.000000      181.000000   0.001489
# 151     39.666668         181.000000      181.000000   0.001489
# 152     40.666668         181.000000      181.000000   0.010603
# 153     40.666668         181.000000      181.000000   0.010603
#
# [154 rows x 42 columns]

# %%
# drop columns we're not using
df['kWh'] = df['Area_km2'] / df['Area / Electricity']
df = df.drop(['Longitude', 'CO2 (g/kWh)', 'CH4 (g/kWh)', 'Area / Electricity', 'Name', 'field_1',
              'temp_spring_avg', 'temp_summer_avg', 'temp_fall_avg', 'temp_winter_avg', 
              'NDVI_spring_avg', 'NDVI_summer_avg', 'NDVI_fall_avg', 'NDVI_winter_avg', 
              'npp_spring_avg' , 'npp_summer_avg' , 'npp_fall_avg' , 'npp_winter_avg'], axis=1)

# %%
df = df.drop(['temp_spring_avg_lc', 'temp_summer_avg_lc', 'temp_fall_avg_lc', 'temp_winter_avg_lc', 
              'NDVI_spring_avg_lc', 'NDVI_summer_avg_lc', 'NDVI_fall_avg_lc', 'NDVI_winter_avg_lc', 
              'npp_spring_avg_lc' , 'npp_summer_avg_lc' , 'npp_fall_avg_lc' , 'npp_winter_avg_lc'], axis=1)

# %%
# rename CO2 and CH4 columns
df.rename(columns = {'CH4 (mg C m-2 d-1)':'CH4', 'CO2 (mg C m¯² d¯¹)':'CO2'}, inplace = True)

# %%
ch4 = df.drop(['CO2'], axis=1)
ch4 = ch4[ch4['CH4'].notna()]

# %%
ch4.shape
# Out:
# (98, 12)

# %%
for column in ch4:
    print(column, ':',  ch4[column].isna().sum())
# Out:
# Latitude : 0
# CH4 : 0
# Area_km2 : 2
# Age : 1
# Volume_km3 : 7
# Areakm2_div_Volkm3 : 8
# org_c : 2
# temp_annual_avg : 0
# NDVI_annual_avg : 0
# npp_annual_avg : 0
# erosion : 0
# kWh : 16

# %%
from sklearn.impute import KNNImputer
model_impute = KNNImputer(n_neighbors=int(np.sqrt(ch4.shape[0])))
ch4_imputed = model_impute.fit_transform(ch4)

# %%
ch4_imputed = pd.DataFrame(columns=ch4.columns, data=ch4_imputed)

# %%
for column in ch4_imputed:
    print(column, ':',  ch4_imputed[column].isna().sum())
# Out:
# Latitude : 0
# CH4 : 0
# Area_km2 : 0
# Age : 0
# Volume_km3 : 0
# Areakm2_div_Volkm3 : 0
# org_c : 0
# temp_annual_avg : 0
# NDVI_annual_avg : 0
# npp_annual_avg : 0
# erosion : 0
# kWh : 0

# %% [markdown]
# ## RF for CH4

# %%
X = ch4_imputed.drop('CH4', axis=1)
Y = ch4_imputed['CH4']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn import ensemble

randomForest = ensemble.RandomForestRegressor()
randomForest.set_params(random_state=42, n_estimators=100, max_features=5)
randomForest.fit(x_train, y_train)
randomForest.score(x_train, y_train)
# Out:
# 0.8546686582241538

# %%
print("The training error is: %.5f" % (1 - randomForest.score(x_train, y_train)))
print("The test     error is: %.5f" % (1 - randomForest.score(x_test, y_test)))
# Out:
# The training error is: 0.14533
# The test     error is: 0.90450

# %%
pd.DataFrame(index=x_train.columns, data=randomForest.feature_importances_*100, columns=['Importance']).sort_values(by='Importance', ascending=True).head(15).plot(kind='barh')

# %%
from sklearn.model_selection import GridSearchCV

grid_values = {
    "n_estimators": range(200,500,50),
    "max_depth" : range(7,16),
    "max_features" : range(7,16)
}

grid_search_forest = GridSearchCV(randomForest, grid_values, scoring='r2', cv=2, n_jobs=-1)
# %time grid_search_forest.fit(x_train, y_train)
# Out:
# CPU times: user 4.78 s, sys: 234 ms, total: 5.01 s
# Wall time: 1min 19s
# GridSearchCV(cv=2, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features=5,
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              oob_score=False, random_state=42,
#                                              verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'max_depth': range(7, 16),
#                          'max_features': range(7, 16),
#                          'n_estimators': range(200, 500, 50)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='r2', verbose=0)

# %%
grid_search_forest.best_params_
# Out:
# {'max_depth': 7, 'max_features': 7, 'n_estimators': 400}

# %%
grid_search_forest.best_score_
# Out:
# -1.1110938880271444
